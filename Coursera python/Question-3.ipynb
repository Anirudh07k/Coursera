# %%
gme_data = yf.download('GME')
gme_data.reset_index(inplace=True)
gme_data.head()
# Out:
# /tmp/ipykernel_3025/2600129004.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   gme_data = yf.download('GME')
# [*********************100%***********************]  1 of 1 completed
# Price        Date      Close       High        Low       Open    Volume
# Ticker                   GME        GME        GME        GME       GME
# 0      2025-10-06  25.049999  25.830000  25.010000  25.549999  11543400
# 1      2025-10-07  24.350000  25.240000  24.309999  25.049999  10779900
# 2      2025-10-08  24.410000  25.049999  24.129999  24.379999   7183800
# 3      2025-10-09  24.070000  24.740000  23.860001  24.580000  11821200
# 4      2025-10-10  23.299999  24.200001  23.280001  24.080000   9744300
