# %%
url = "https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")
tables = soup.find_all("table")
gme_revenue.columns = ["Date", "Revenue"]
gme_revenue = gme_revenue[gme_revenue["Revenue"] != ""]
gme_revenue["Revenue"] = gme_revenue["Revenue"].str.replace(r"[\$,]", "", regex=True)
gme_revenue["Revenue"] = pd.to_numeric(gme_revenue["Revenue"], errors="coerce")
gme_revenue.dropna(inplace=True)
gme_revenue = gme_revenue.reset_index(drop=True)
# Display the last 5 rows
gme_revenue.tail()
# Out:
# Source used: Macrotrends (web scraping)
# /tmp/ipykernel_3276/1195850540.py:27: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(r.text, match="GameStop Quarterly Revenue")
#          Date  Revenue
# 54 2024-07-31      798
# 55 2024-10-31      860
# 56 2025-01-31     1283
# 57 2025-04-30      732
# 58 2025-07-31      972
