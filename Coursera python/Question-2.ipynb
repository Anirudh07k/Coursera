# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data, "html.parser")

for table in soup.find_all('table'):
    if "Tesla Quarterly Revenue" in str(table):
        tesla_revenue = pd.read_html(str(table))[0]
        break
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of Tesla revenue page
url = "https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"

# Send a request to fetch HTML content
html_data = requests.get(url).text

# Parse with BeautifulSoup
soup = BeautifulSoup(html_data, "html.parser")

# Find all HTML tables on the page
tables = soup.find_all("table")

# Convert the first valid table into a DataFrame
for table in tables:
    df = pd.read_html(str(table))[0]
    if "Revenue" in df.columns[1]:  # Check if second column is Revenue
        tesla_revenue = df
        break

# Clean the dataframe
tesla_revenue.columns = ["Date", "Revenue"]
tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]
tesla_revenue.dropna(inplace=True)

# Display last 5 rows
tesla_revenue.tail()


tesla_revenue.columns = ["Date", "Revenue"]
tesla_revenue = tesla_revenue[tesla_revenue["Revenue"] != ""]
tesla_revenue.dropna(inplace=True)

tesla_revenue.tail()
# Out:
#         Date       Revenue
# 1 2024-06-30  2.550000e+10
# 2 2024-09-30  2.518200e+10
# 3 2024-12-31  2.570700e+10
# 4 2025-03-31  1.933500e+10
# 5 2025-06-30  2.249600e+10
