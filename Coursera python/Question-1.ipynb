# %%
# !pip install yfinance

import yfinance as yf
import pandas as pd
tesla_data = yf.download('TSLA')

tesla_data.reset_index(inplace=True)

tesla_data.head()
# Out:
# /tmp/ipykernel_2621/10017336.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla_data = yf.download('TSLA')
# [*********************100%***********************]  1 of 1 completed
# Price        Date       Close        High         Low        Open     Volume
# Ticker                   TSLA        TSLA        TSLA        TSLA       TSLA
# 0      2025-10-06  453.250000  453.549988  436.690002  440.750000   85324900
# 1      2025-10-07  433.089996  452.679993  432.450012  447.820007  102296100
# 2      2025-10-08  438.690002  441.329987  425.230011  437.570007   71192100
# 3      2025-10-09  435.540009  436.350006  426.179993  431.809998   69339900
# 4      2025-10-10  413.489990  443.130005  411.450012  436.540009  112107900
